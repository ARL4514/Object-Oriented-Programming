# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Object-Oriented-Programming/blob/Jobsheet-1/JOBSHEET_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JOBSHEET 05: POLIMORFISME DAN MEMAHAMI OVERLOADING/OVERRIDING

# %% [markdown]
# Praktikum 01: Polimorfisme dengan Inheritance dan Overriding

# %%
import inspect
# Kelas Induk
class Burung:
  def __init__(self, nama):
    self.nama = nama

  def terbang(self):
    print(f"{self.nama} terbang dengan cara umum.")

  def bersuara(self):
    print(f"{self.nama} mengeluarkan suara burung.")

# Kelas Anak 1
class Elang(Burung):
  def __init__(self, nama, rentang_sayap):
    super().__init__(nama)
    self.rentang_sayap = rentang_sayap

  #Override
  def terbang(self):
    print(f"{self.nama} terbang tinggi melayang di angkasa.")

  #Override
  def bersuara(self):
    print(f"{self.nama} berteriak nyaring!")

# Kelas Anak 2
class Pipit(Burung):
    def __init__(self, nama, warna_bulu):
        super().__init__(nama)
        self.warna_bulu = warna_bulu

    # Override
    def terbang(self):
        print(f"{self.nama} terbang cepat di antara pepohonan.")

    # Override
    def bersuara(self):
        print(f"{self.nama} berkicau merdu: Cit cit!")

# Fungsi yang memanfaatkan polimorfisme
def demonstrasi_aksi_burung(daftar_burung):
    print("\nAksi Burung:")
    for burung in daftar_burung:
        print(f"-- Aksi untuk {burung.nama} --")
        # Panggilan metode yang sama, tapi perilaku berbeda tergantung objek
        burung.terbang()
        burung.bersuara()
        print("-" * 15)

# --- Kode Utama ---
if __name__ == "__main__":
    elang_jawa = Elang("Elang Jawa", 1.5)
    pipit_gereja = Pipit("Pipit Gereja", "Coklat")
    burung_aneh = Burung("Burung Misterius") # Objek dari kelas induk

    koleksi_burung = [elang_jawa, pipit_gereja, burung_aneh]

    demonstrasi_aksi_burung(koleksi_burung)
# Out:
# Aksi Burung:
# -- Aksi untuk Elang Jawa --
# Elang Jawa terbang tinggi melayang di angkasa.
# Elang Jawa berteriak nyaring!
# ---------------
# -- Aksi untuk Pipit Gereja --
# Pipit Gereja terbang cepat di antara pepohonan.
# Pipit Gereja berkicau merdu: Cit cit!
# ---------------
# -- Aksi untuk Burung Misterius --
# Burung Misterius terbang dengan cara umum.
# Burung Misterius mengeluarkan suara burung.
# ---------------

# %% [markdown]
# Praktikum 02: Polimorfisme dengan Duck Typing

# %%
class Kucing:
    def bersuara(self):
        print("Kucing: Meow!")

class Anjing:
    def bersuara(self):
        print("Anjing: Guk guk!")

class Bebek:
    def bersuara(self):
        print("Bebek: Kwek kwek!")

class Mobil: # Kelas ini TIDAK punya metode bersuara()
    def jalankan(self):
        print("Mobil: Brummm!")

# Fungsi ini tidak peduli tipe objeknya,
# asal punya metode .bersuara()
def buat_suara(objek_yang_bisa_bersuara):
    try:
        # Memanggil metode 'bersuara' jika ada
        objek_yang_bisa_bersuara.bersuara()
    except AttributeError:
        # Menangani jika objek tidak punya metode 'bersuara'
        print(f"Objek {type(objek_yang_bisa_bersuara).__name__} tidak bisa bersuara.")

# --- Kode Utama ---
if __name__ == "__main__":
    kucing1 = Kucing()
    anjing1 = Anjing()
    bebek1 = Bebek()
    mobil1 = Mobil()

    daftar_objek = [kucing1, anjing1, bebek1, mobil1]

    print("Demonstrasi Duck Typing:")
    for item in daftar_objek:
        buat_suara(item) # Fungsi polimorfik via duck typing
# Out:
# Demonstrasi Duck Typing:
# Kucing: Meow!
# Anjing: Guk guk!
# Bebek: Kwek kwek!
# Objek Mobil tidak bisa bersuara.

# %% [markdown]
# Praktikum 03: Simulasi Overloading dalam Metode Kelas dengan *args

# %%
class KalkulatorSederhana:
  def __init__(self, nama="Kalkulator"):
    self.nama = nama
    print(f"{self.nama} siap digunakan.")

  def tambah(self, *args):
    """
    Metode ini menjumlahkan semua argumen angka yang diberikan.
    Menerima sejumlah argumen posisi menggunakan *args.
    """
    print(f"\nMemanggil metode tambah dengan argumen: {args}")
    if not args:
      print("Tidak ada angka untuk dijumlahkan.")
      return 0 # Atau bisa juga None atau raise error

    total = 0
    valid_input = True
    for angka in args:
      # Melakukan pengecekan tipe sederhana
      if isinstance(angka, (int, float)):
        total += angka
      else:
        print(f"Peringatan: Argumen '{angka}' bukan angka dan akan diabaikan.")
        valid_input = False
    if valid_input:
      print(f"Hasil Penjumlahan: {total}")
    else:
      print(f"Hasil penjumlahan (dengan beberapa input diabaikan):{total}")
    return total

# ---Kode Utama---
if __name__=="__main__":
  calc = KalkulatorSederhana("Calc-01")

  # Memanggil metode 'tambah' dengan jumlah argumen berbeda
  print("\n--- Percobaan Penjumlahan ---")
  calc.tambah(5, 10)
  calc.tambah(2, 3, 5, 10)
  calc.tambah(100)
  calc.tambah() # Tanpa argumen
  calc.tambah(1, 2, "tiga", 4, 5.5) # Dengan input non-angka
# Out:
# Calc-01 siap digunakan.
#
# --- Percobaan Penjumlahan ---
#
# Memanggil metode tambah dengan argumen: (5, 10)
# Hasil Penjumlahan: 15
#
# Memanggil metode tambah dengan argumen: (2, 3, 5, 10)
# Hasil Penjumlahan: 20
#
# Memanggil metode tambah dengan argumen: (100,)
# Hasil Penjumlahan: 100
#
# Memanggil metode tambah dengan argumen: ()
# Tidak ada angka untuk dijumlahkan.
#
# Memanggil metode tambah dengan argumen: (1, 2, 'tiga', 4, 5.5)
# Peringatan: Argumen 'tiga' bukan angka dan akan diabaikan.
# Hasil penjumlahan (dengan beberapa input diabaikan):12.5

# %% [markdown]
# Praktikum 04: Simulasi Overloading dalam Metode Kelas dengan *args dan **kwargs

# %%
class DataProcessor:
    def __init__(self, processor_id):
        self.processor_id = processor_id
        print(f"Data Processor {self.processor_id} siap.")

    def process(self, *args, **kwargs):
        """
        Metode ini memproses data dengan argumen posisi (*args)
        dan kata kunci (**kwargs) yang jumlahnya variabel.
        """
        print(f"\n--- {self.processor_id} Memproses Data ---")

        # Memproses argumen posisi (*args -> tuple)
        if args:
            print("Argumen Posisi Diterima:")
            for i, arg in enumerate(args):
                print(f" args[{i}]: {arg} (tipe: {type(arg).__name__})")
        else:
            print("Tidak ada argumen posisi.")

        # Memproses argumen kata kunci (**kwargs -> dict)
        if kwargs:
            print("Argumen Kata Kunci Diterima:")
            for kunci, nilai in kwargs.items():
                print(f" {kunci}: {nilai} (tipe: {type(nilai).__name__})")
        else:
            print("Tidak ada argumen kata kunci.")
        print("------------------------------------------")

# --- Kode Utama ---

if __name__ == "__main__":
    # Membuat instance dari kelas
    processor1 = DataProcessor("DP-001")

    # Memanggil metode 'process' dengan berbagai cara
    print("\nPanggilan 1: Tanpa argumen tambahan")
    processor1.process()

    print("\nPanggilan 2: Hanya argumen posisi")
    processor1.process(100, "Status OK", 99.9, False)

    print("\nPanggilan 3: Hanya argumen kata kunci")
    processor1.process(user="admin", level=5, mode="verbose")

    print("\nPanggilan 4: Kombinasi argumen posisi dan kata kunci")
    processor1.process("Task-A", "Task-B", status="Running", priority="High", thread_id=54321)

    # Panggilan dengan list dan dictionary sebagai argumen posisi
    print("\nPanggilan 5: Argumen posisi kompleks")
    list_ids = ["A1", "B2", "C3"]
    dict_params = {"timeout": 30, "retry": 3}
    processor1.process(list_ids, dict_params, owner="system", enabled=True)
# Out:
# Data Processor DP-001 siap.
#
# Panggilan 1: Tanpa argumen tambahan
#
# --- DP-001 Memproses Data ---
# Tidak ada argumen posisi.
# Tidak ada argumen kata kunci.
# ------------------------------------------
#
# Panggilan 2: Hanya argumen posisi
#
# --- DP-001 Memproses Data ---
# Argumen Posisi Diterima:
#  args[0]: 100 (tipe: int)
#  args[1]: Status OK (tipe: str)
#  args[2]: 99.9 (tipe: float)
#  args[3]: False (tipe: bool)
# Tidak ada argumen kata kunci.
# ------------------------------------------
#
# Panggilan 3: Hanya argumen kata kunci
#
# --- DP-001 Memproses Data ---
# Tidak ada argumen posisi.
# Argumen Kata Kunci Diterima:
#  user: admin (tipe: str)
#  level: 5 (tipe: int)
#  mode: verbose (tipe: str)
# ------------------------------------------
#
# Panggilan 4: Kombinasi argumen posisi dan kata kunci
#
# --- DP-001 Memproses Data ---
# Argumen Posisi Diterima:
#  args[0]: Task-A (tipe: str)
#  args[1]: Task-B (tipe: str)
# Argumen Kata Kunci Diterima:
#  status: Running (tipe: str)
#  priority: High (tipe: str)
#  thread_id: 54321 (tipe: int)
# ------------------------------------------
#
# Panggilan 5: Argumen posisi kompleks
#
# --- DP-001 Memproses Data ---
# Argumen Posisi Diterima:
#  args[0]: ['A1', 'B2', 'C3'] (tipe: list)
#  args[1]: {'timeout': 30, 'retry': 3} (tipe: dict)
# Argumen Kata Kunci Diterima:
#  owner: system (tipe: str)
#  enabled: True (tipe: bool)
# ------------------------------------------

# %% [markdown]
# Praktikum 05: Kombinasi Polimorfisme (Inheritance & Duck Typing)

# %%
import math

# --- Definisi Kelas dari Hierarki Inheritance ---
class Bentuk:
    # Metode ini bisa dianggap sebagai 'template' atau interface dasar
    def nama_bentuk(self):
        return "Bentuk Generik"

    # Metode ini wajib di-override oleh subclass
    def hitung_luas(self):
        raise NotImplementedError("Subclass harus mengimplementasikan metode ini")

class Lingkaran(Bentuk):
    def __init__(self, radius):
        self.radius = radius

    # Override
    def nama_bentuk(self):
        return "Lingkaran"

    # Override
    def hitung_luas(self):
        return math.pi * (self.radius ** 2)

class Persegi(Bentuk):
    def __init__(self, sisi):
        self.sisi = sisi

    # Override
    def nama_bentuk(self):
        return "Persegi"

    # Override
    def hitung_luas(self):
        return self.sisi * self.sisi

# --- Definisi Kelas Lain (Tidak Terkait Inheritance dengan Bentuk) ---
class TaplakMeja:
    def __init__(self, panjang, lebar):
        self.panjang = panjang
        self.lebar = lebar

    # Metode dengan nama sama -> 'hitung luas'
    # Ini memungkinkan TaplakMeja bekerja dengan fungsi polimorfik di bawah
    def hitung_luas(self):
        return self.panjang * self.lebar

    # Metode yang berbeda, tidak ada di kelas Bentuk
    def deskripsi(self):
        return f"Taplak Meja {self.panjang}x{self.lebar}"

# --- Fungsi Polimorfik ---
def tampilkan_info_luas(objek_dengan_luas):
    print("-" * 20)
    try:
        # Mencoba memanggil hitung_luas() - inti polimorfisme
        luas = objek_dengan_luas.hitung_luas()

        # Mencoba mendapatkan nama jika ada (duck typing tambahan)
        try:
            nama = objek_dengan_luas.nama_bentuk()
        except AttributeError:
            # Jika tidak ada nama_bentuk(), gunakan nama kelasnya
            nama = type(objek_dengan_luas).__name__

        print(f"Objek: {nama}")
        print(f"Luas : {luas:.2f}") # Format luas 2 angka desimal

    except AttributeError:
        # Menangani jika objek sama sekali tidak punya .hitung_luas()
        print(f"Objek {type(objek_dengan_luas).__name__} tidak dapat dihitung luasnya (metode tidak ditemukan).")

    except NotImplementedError:
        # Menangani jika metode ada tapi belum diimplementasi (dari kelas Bentuk)
        print(f"Metode 'hitung_luas' belum diimplementasi untuk {type(objek_dengan_luas).__name__}.")

# --- Kode Utama ---
if __name__ == "__main__":
    lingkaran1 = Lingkaran(7)
    persegi1 = Persegi(5)
    taplak1 = TaplakMeja(1.5, 0.8)
    bentuk_dasar = Bentuk() # Objek kelas induk (akan raise NotImplementedError)
    string_biasa = "Ini string" # Objek yang tidak relevan

    daftar_item = [lingkaran1, persegi1, taplak1, bentuk_dasar, string_biasa]

    print("Menampilkan Info Luas (Polimorfisme Campuran):")
    for item in daftar_item:
        tampilkan_info_luas(item)
# Out:
# Menampilkan Info Luas (Polimorfisme Campuran):
# --------------------
# Objek: Lingkaran
# Luas : 153.94
# --------------------
# Objek: Persegi
# Luas : 25.00
# --------------------
# Objek: TaplakMeja
# Luas : 1.20
# --------------------
# Metode 'hitung_luas' belum diimplementasi untuk Bentuk.
# --------------------
# Objek str tidak dapat dihitung luasnya (metode tidak ditemukan).

# %% [markdown]
# Praktikum 06: Kontrol Perilaku Polimorfik dengan isinstance()

# %%
# --- Definisi Kelas Burung, Elang, Pipit ---
class Burung:
    def __init__(self, nama):
        self.nama = nama

    def terbang(self):
        print(f"{self.nama} terbang dengan cara umum.")

    def bersuara(self):
        print(f"{self.nama} mengeluarkan suara burung.")

class Elang(Burung):
    def __init__(self, nama, rentang_sayap):
        super().__init__(nama)
        self.rentang_sayap = rentang_sayap

    # Override
    def terbang(self):
        print(f"{self.nama} terbang tinggi melayang di angkasa.")

    # Override
    def bersuara(self):
        print(f"{self.nama} berteriak nyaring!")

    # Metode khusus Elang
    def berburu(self):
        print(f"{self.nama} sedang mencari mangsa dari ketinggian.")

class Pipit(Burung):
    def __init__(self, nama, warna_bulu):
        super().__init__(nama)
        self.warna_bulu = warna_bulu

    # Override
    def terbang(self):
        print(f"{self.nama} terbang cepat di antara pepohonan.")

    # Override
    def bersuara(self):
        print(f"{self.nama} berkicau merdu: Cit cit!")

    # Metode khusus Pipit
    def membangun_sarang(self):
        print(f"{self.nama} sedang mengumpulkan ranting untuk sarang.")

# --- Fungsi yang memanfaatkan polimorfisme DAN isinstance() ---
def interaksi_dengan_burung(burung):
    print(f"\n--- Berinteraksi dengan {type(burung).__name__}: {getattr(burung, 'nama', 'Objek tidak dikenal')} ---")

    # Cek dulu apakah objek adalah instance dari Burung atau turunannya
    if isinstance(burung, Burung):
        # Perilaku polimorfik dasar (memanggil metode override)
        burung.terbang()
        burung.bersuara()

        # Menambahkan perilaku spesifik berdasarkan tipe turunan
        if isinstance(burung, Elang):
            print("-> Ini adalah Elang!")
            burung.berburu() # Panggil metode khusus Elang
        elif isinstance(burung, Pipit):
            print("-> Ini adalah Pipit!")
            burung.membangun_sarang() # Panggil metode khusus Pipit
        else:
            # Hanya Burung generik, bukan turunan spesifik yang dikenali
            print("-> Ini adalah burung jenis umum (bukan Elang/Pipit).")
    else:
        # Jika objek BUKAN instance Burung sama sekali
        print("-> Objek ini bukan termasuk jenis Burung.")

    print("-" * 25)

# --- Kode Utama ---
if __name__ == "__main__":
    elang_sumatra = Elang("Elang Sumatra", 1.8)
    pipit_rumah = Pipit("Pipit Rumah", "Abu-abu")
    merak = Burung("Merak") # Contoh Burung lain (induk)
    kucing_tetangga = "Meong" # Objek non-burung

    koleksi_makhluk = [elang_sumatra, pipit_rumah, merak, kucing_tetangga]

    for makhluk in koleksi_makhluk:
        interaksi_dengan_burung(makhluk)
# Out:
# --- Berinteraksi dengan Elang: Elang Sumatra ---
# Elang Sumatra terbang tinggi melayang di angkasa.
# Elang Sumatra berteriak nyaring!
# -> Ini adalah Elang!
# Elang Sumatra sedang mencari mangsa dari ketinggian.
# -------------------------
#
# --- Berinteraksi dengan Pipit: Pipit Rumah ---
# Pipit Rumah terbang cepat di antara pepohonan.
# Pipit Rumah berkicau merdu: Cit cit!
# -> Ini adalah Pipit!
# Pipit Rumah sedang mengumpulkan ranting untuk sarang.
# -------------------------
#
# --- Berinteraksi dengan Burung: Merak ---
# Merak terbang dengan cara umum.
# Merak mengeluarkan suara burung.
# -> Ini adalah burung jenis umum (bukan Elang/Pipit).
# -------------------------
#
# --- Berinteraksi dengan str: Objek tidak dikenal ---
# -> Objek ini bukan termasuk jenis Burung.
# -------------------------

# %% [markdown]
# PENUGASAN

# %% [markdown]
# 3.	Buat Program dan Kelas diagram

# %%
# === POIN 1: KELAS INDUK ===
class Komputer:
    def __init__(self, merk, processor, ram_gb):
        self.merk = merk
        self.processor = processor
        self.ram_gb = ram_gb

    def info_spesifikasi(self):
        print(f"Merk: {self.merk}")
        print(f"Processor: {self.processor}")
        print(f"RAM: {self.ram_gb} GB")

    def jalankan_aplikasi(self, nama_aplikasi):
        print(f"[{self.merk}] menjalankan aplikasi: {nama_aplikasi}...")

    # === POIN 5: SIMULASI OVERLOADING (Opsi B - *args) ===
    def install_software(self, *args):
        if args:
            for software in args:
                print(f"Menginstall {software} di {self.merk}...")
        else:
            print(f"Tidak ada software yang ditentukan untuk diinstall.")

# === POIN 2: KELAS ANAK 1 (LAPTOP) ===
class Laptop(Komputer):
    def __init__(self, merk, processor, ram_gb, ukuran_layar_inch, berat_kg):
        # Menggunakan super() untuk inisialisasi bagian Komputer
        super().__init__(merk, processor, ram_gb)
        self.ukuran_layar_inch = ukuran_layar_inch
        self.berat_kg = berat_kg

    # Override metode info_spesifikasi
    def info_spesifikasi(self):
        super().info_spesifikasi()
        print(f"Ukuran Layar: {self.ukuran_layar_inch} inch")
        print(f"Berat: {self.berat_kg} Kg")

# === POIN 3: KELAS ANAK 2 (DESKTOP) ===
class Desktop(Komputer):
    def __init__(self, merk, processor, ram_gb, jenis_casing, monitor_external):
        super().__init__(merk, processor, ram_gb)
        self.jenis_casing = jenis_casing
        self.monitor_external = monitor_external

    # Override metode info_spesifikasi
    def info_spesifikasi(self):
        super().info_spesifikasi()
        status_monitor = "Ya" if self.monitor_external else "Tidak"
        print(f"Jenis Casing: {self.jenis_casing}")
        print(f"Monitor External: {status_monitor}")

# === POIN 4: DEMONSTRASI POLIMORFISME ===
def cetak_semua_spesifikasi(daftar_komputer):
    print("\n" + "="*10 + " DAFTAR SPESIFIKASI " + "="*10)
    for komputer in daftar_komputer:
        komputer.info_spesifikasi()
        print("-" * 30)

# === POIN 6: KODE UTAMA ===
if __name__ == "__main__":
    # Membuat objek Laptop dan Desktop
    laptop_pro = Laptop("MacBook", "M2", 16, 13.3, 1.2)
    desktop_gaming = Desktop("ASUS ROG", "Ryzen 9", 32, "Tower", True)

    # Masukkan ke dalam list
    koleksi_perangkat = [laptop_pro, desktop_gaming]

    # Memanggil fungsi polimorfisme
    cetak_semua_spesifikasi(koleksi_perangkat)

    # Demonstrasi Overloading (*args)
    print("\n[Demonstrasi Overloading]")
    # Dengan satu software
    laptop_pro.install_software("VS Code")

    print() # Jarak

    # Dengan beberapa software sekaligus
    desktop_gaming.install_software("Steam", "Discord", "Spotify")
# Out:
# ========== DAFTAR SPESIFIKASI ==========
# Merk: MacBook
# Processor: M2
# RAM: 16 GB
# Ukuran Layar: 13.3 inch
# Berat: 1.2 Kg
# ------------------------------
# Merk: ASUS ROG
# Processor: Ryzen 9
# RAM: 32 GB
# Jenis Casing: Tower
# Monitor External: Ya
# ------------------------------
#
# [Demonstrasi Overloading]
# Menginstall VS Code di MacBook...
#
# Menginstall Steam di ASUS ROG...
# Menginstall Discord di ASUS ROG...
# Menginstall Spotify di ASUS ROG...

# %% [markdown]
# Kelas Induk (Komputer)

# %%
class Komputer:
    def __init__(self, merk, processor, ram_gb):
        """
        Konstruktor untuk menginisialisasi atribut dasar komputer.
        Atribut:
        - merk (string)
        - processor (string)
        - ram_gb (integer)
        """
        self.merk = str(merk)
        self.processor = str(processor)
        self.ram_gb = int(ram_gb)

    def info_spesifikasi(self):
        """
        Mencetak informasi dasar komputer.
        """
        print(f"Merk: {self.merk}")
        print(f"Processor: {self.processor}")
        print(f"RAM: {self.ram_gb} GB")

    def jalankan_aplikasi(self, nama_aplikasi):
        """
        Mencetak pesan bahwa komputer sedang menjalankan aplikasi tertentu.
        """
        print(f"[{self.merk}] menjalankan aplikasi: {nama_aplikasi}...")

# --- Contoh Penggunaan ---
if __name__ == "__main__":
    # Membuat objek komputer baru
    pc_saya = Komputer("Lenovo", "Intel i7", 16)

    # Menampilkan info spesifikasi
    print("--- Info Komputer ---")
    pc_saya.info_spesifikasi()

    # Menjalankan aplikasi
    print("\n--- Aktivitas ---")
    pc_saya.jalankan_aplikasi("Adobe Premiere")
# Out:
# --- Info Komputer ---
# Merk: Lenovo
# Processor: Intel i7
# RAM: 16 GB
#
# --- Aktivitas ---
# [Lenovo] menjalankan aplikasi: Adobe Premiere...

# %% [markdown]
# Kelas Anak 1 (Laptop)

# %%
class Laptop(Komputer):
    def __init__(self, merk, processor, ram_gb, ukuran_layar_inch, berat_kg):
        """
        Konstruktor untuk Laptop.
        Menerima atribut komputer dasar + spesifikasi fisik laptop.
        """
        # Menginisialisasi atribut merk, processor, dan ram_gb dari kelas induk (Komputer)
        super().__init__(merk, processor, ram_gb)

        # Atribut tambahan khusus Laptop
        self.ukuran_layar_inch = float(ukuran_layar_inch)
        self.berat_kg = float(berat_kg)

    def info_spesifikasi(self):
        """
        Override metode info_spesifikasi untuk menambahkan detail fisik laptop.
        """
        # Memanggil metode info_spesifikasi milik kelas induk
        super().info_spesifikasi()

        # Menambahkan informasi tambahan khusus laptop
        print(f"Ukuran Layar: {self.ukuran_layar_inch} inch")
        print(f"Berat: {self.berat_kg} Kg")

# --- Contoh Penggunaan ---
if __name__ == "__main__":
    # Membuat objek Laptop
    laptop_baru = Laptop("MacBook Pro", "M2 Chip", 16, 14.2, 1.6)

    print("--- Spesifikasi Laptop ---")
    laptop_baru.info_spesifikasi()
# Out:
# --- Spesifikasi Laptop ---
# Merk: MacBook Pro
# Processor: M2 Chip
# RAM: 16 GB
# Ukuran Layar: 14.2 inch
# Berat: 1.6 Kg

# %% [markdown]
# Kelas Anak 2 (Desktop)

# %%
class Desktop(Komputer):
    def __init__(self, merk, processor, ram_gb, jenis_casing, monitor_external):
        """
        Konstruktor untuk Desktop.
        Menerima atribut komputer dasar + spesifikasi fisik desktop.
        """
        # Menginisialisasi bagian Komputer menggunakan super()
        super().__init__(merk, processor, ram_gb)

        # Atribut tambahan khusus Desktop
        self.jenis_casing = str(jenis_casing)
        self.monitor_external = bool(monitor_external)

    def info_spesifikasi(self):
        """
        Override metode info_spesifikasi untuk menambahkan detail casing dan monitor.
        """
        # Memanggil metode info_spesifikasi milik kelas induk (Komputer)
        super().info_spesifikasi()

        # Logika untuk mengubah Boolean menjadi teks Ya/Tidak
        status_monitor = "Ya" if self.monitor_external else "Tidak"

        # Menambahkan informasi tambahan khusus desktop
        print(f"Jenis Casing: {self.jenis_casing}")
        print(f"Monitor External: {status_monitor}")

# --- Contoh Penggunaan ---
if __name__ == "__main__":
    # Membuat objek Desktop
    desktop_gaming = Desktop("MSI Aegis", "Intel i9", 32, "Tower", True)

    print("--- Spesifikasi Desktop ---")
    desktop_gaming.info_spesifikasi()
# Out:
# --- Spesifikasi Desktop ---
# Merk: MSI Aegis
# Processor: Intel i9
# RAM: 32 GB
# Jenis Casing: Tower
# Monitor External: Ya

# %% [markdown]
# Demonstrasi Polimorfisme

# %%
def cetak_semua_spesifikasi(daftar_komputer):
    """
    Fungsi polimorfik untuk menampilkan spesifikasi dari berbagai jenis komputer.
    Fungsi ini tidak peduli apakah objeknya Laptop atau Desktop,
    ia hanya memanggil metode .info_spesifikasi() yang dimiliki keduanya.
    """
    print("=" * 10, "LAPORAN SPESIFIKASI", "=" * 10)

    for i, komputer in enumerate(daftar_komputer, 1):
        print(f"\nKomputer ke-{i}:")

        # Inilah letak Polimorfisme:
        # Satu pemanggilan metode yang sama (.info_spesifikasi()),
        # namun menghasilkan format output yang berbeda-beda.
        komputer.info_spesifikasi()

    print("\n" + "=" * 41)

# --- Contoh Pengujian Polimorfisme ---
if __name__ == "__main__":
    # Menyiapkan beberapa objek berbeda
    laptop_1 = Laptop("HP Pavilion", "Ryzen 7", 16, 14.0, 1.4)
    desktop_1 = Desktop("Acer Nitro", "Intel i5", 8, "Mini-PC", False)
    laptop_2 = Laptop("ThinkPad", "Intel i7", 32, 13.3, 1.2)

    # Memasukkan objek ke dalam satu list (daftar_komputer)
    koleksi = [laptop_1, desktop_1, laptop_2]

    # Menjalankan fungsi polimorfisme
    cetak_semua_spesifikasi(koleksi)
# Out:
# ========== LAPORAN SPESIFIKASI ==========
#
# Komputer ke-1:
# Merk: HP Pavilion
# Processor: Ryzen 7
# RAM: 16 GB
# Ukuran Layar: 14.0 inch
# Berat: 1.4 Kg
#
# Komputer ke-2:
# Merk: Acer Nitro
# Processor: Intel i5
# RAM: 8 GB
# Jenis Casing: Mini-PC
# Monitor External: Tidak
#
# Komputer ke-3:
# Merk: ThinkPad
# Processor: Intel i7
# RAM: 32 GB
# Ukuran Layar: 13.3 inch
# Berat: 1.2 Kg
#
# =========================================

# %% [markdown]
# Simulasi Overloading

# %%
class Komputer:
    def __init__(self, merk, processor, ram_gb):
        """
        Konstruktor untuk menginisialisasi atribut dasar komputer.
        Atribut:
        - merk (string)
        - processor (string)
        - ram_gb (integer)
        """
        self.merk = str(merk)
        self.processor = str(processor)
        self.ram_gb = int(ram_gb)

    def info_spesifikasi(self):
        """
        Mencetak informasi dasar komputer.
        """
        print(f"Merk: {self.merk}")
        print(f"Processor: {self.processor}")
        print(f"RAM: {self.ram_gb} GB")

    def jalankan_aplikasi(self, nama_aplikasi):
        """
        Mencetak pesan bahwa komputer sedang menjalankan aplikasi tertentu.
        """
        print(f"[{self.merk}] menjalankan aplikasi: {nama_aplikasi}...")

    def install_software(self, *args):
        """
        Simulasi Overloading menggunakan *args.
        Metode ini bisa menerima satu atau lebih nama software.
        """
        if args:
            print(f"--- Memulai Instalasi di {self.merk} ---")
            for software in args:
                print(f"Menginstall {software} di {self.merk}...")
        else:
            print(f"Tidak ada software yang diinputkan untuk {self.merk}.")

# --- Contoh Pengujian Simulasi Overloading ---
if __name__ == "__main__":
    # Inisialisasi objek
    pc_kantor = Komputer("Lenovo ThinkCentre", "Intel i5", 8)

    # Pemanggilan 1: Dengan satu argumen
    print("Panggilan 1 (Satu Software):")
    pc_kantor.install_software("Google Chrome")

    print("-" * 30)

    # Pemanggilan 2: Dengan banyak argumen (Simulasi Overloading)
    print("Panggilan 2 (Banyak Software):")
    pc_kantor.install_software("Visual Studio Code", "Docker", "Git", "Postman")
# Out:
# Panggilan 1 (Satu Software):
# --- Memulai Instalasi di Lenovo ThinkCentre ---
# Menginstall Google Chrome di Lenovo ThinkCentre...
# ------------------------------
# Panggilan 2 (Banyak Software):
# --- Memulai Instalasi di Lenovo ThinkCentre ---
# Menginstall Visual Studio Code di Lenovo ThinkCentre...
# Menginstall Docker di Lenovo ThinkCentre...
# Menginstall Git di Lenovo ThinkCentre...
# Menginstall Postman di Lenovo ThinkCentre...

# %% [markdown]
# Kode Utama

# %%
import math

# --- 1. Definisi Kelas Induk ---
class Komputer:
    def __init__(self, merk, processor, ram_gb):
        self.merk = merk
        self.processor = processor
        self.ram_gb = ram_gb

    def info_spesifikasi(self):
        print(f"Merk: {self.merk}")
        print(f"Processor: {self.processor}")
        print(f"RAM: {self.ram_gb} GB")

    def jalankan_aplikasi(self, nama_aplikasi):
        print(f"[{self.merk}] menjalankan aplikasi: {nama_aplikasi}...")

    # Langkah 5: Simulasi Overloading (Opsi B: *args)
    def install_software(self, *args):
        if args:
            for software in args:
                print(f"Menginstall {software} di {self.merk}...")
        else:
            print(f"Tidak ada software yang dipilih untuk {self.merk}.")

# --- 2. Definisi Kelas Anak 1 ---
class Laptop(Komputer):
    def __init__(self, merk, processor, ram_gb, ukuran_layar_inch, berat_kg):
        super().__init__(merk, processor, ram_gb)
        self.ukuran_layar_inch = ukuran_layar_inch
        self.berat_kg = berat_kg

    def info_spesifikasi(self):
        super().info_spesifikasi()
        print(f"Ukuran Layar: {self.ukuran_layar_inch} inch")
        print(f"Berat: {self.berat_kg} Kg")

# --- 3. Definisi Kelas Anak 2 ---
class Desktop(Komputer):
    def __init__(self, merk, processor, ram_gb, jenis_casing, monitor_external):
        super().__init__(merk, processor, ram_gb)
        self.jenis_casing = jenis_casing
        self.monitor_external = monitor_external

    def info_spesifikasi(self):
        super().info_spesifikasi()
        status_monitor = "Ya" if self.monitor_external else "Tidak"
        print(f"Jenis Casing: {self.jenis_casing}")
        print(f"Monitor External: {status_monitor}")

# --- 4. Fungsi Polimorfisme ---
def cetak_semua_spesifikasi(daftar_komputer):
    print("=== DAFTAR SPESIFIKASI KOMPUTER ===")
    for komputer in daftar_komputer:
        komputer.info_spesifikasi()
        print("-" * 30)

# --- 6. KODE UTAMA ---
if __name__ == "__main__":
    # a. Buat minimal satu objek Laptop dan satu objek Desktop
    laptop_gaming = Laptop("MSI Stealth", "Intel i7", 16, 15.6, 1.9)
    desktop_studio = Desktop("Apple Mac Studio", "M2 Ultra", 64, "Mini-PC", True)

    # b. Masukkan objek-objek tersebut ke dalam sebuah list
    koleksi_perangkat = [laptop_gaming, desktop_studio]

    # c. Panggil fungsi cetak_semua_spesifikasi()
    cetak_semua_spesifikasi(koleksi_perangkat)

    # d. Demonstrasikan pemanggilan metode simulasi overloading (*args)
    print("\n[Demonstrasi Simulasi Overloading: install_software]")

    # Memanggil dengan satu software pada objek laptop
    print(f"Panggilan 1:")
    laptop_gaming.install_software("Steam")

    print("-" * 15)

    # Memanggil dengan banyak software pada objek desktop
    print(f"Panggilan 2:")
    desktop_studio.install_software("Final Cut Pro", "Logic Pro", "DaVinci Resolve")
# Out:
# === DAFTAR SPESIFIKASI KOMPUTER ===
# Merk: MSI Stealth
# Processor: Intel i7
# RAM: 16 GB
# Ukuran Layar: 15.6 inch
# Berat: 1.9 Kg
# ------------------------------
# Merk: Apple Mac Studio
# Processor: M2 Ultra
# RAM: 64 GB
# Jenis Casing: Mini-PC
# Monitor External: Ya
# ------------------------------
#
# [Demonstrasi Simulasi Overloading: install_software]
# Panggilan 1:
# Menginstall Steam di MSI Stealth...
# ---------------
# Panggilan 2:
# Menginstall Final Cut Pro di Apple Mac Studio...
# Menginstall Logic Pro di Apple Mac Studio...
# Menginstall DaVinci Resolve di Apple Mac Studio...
