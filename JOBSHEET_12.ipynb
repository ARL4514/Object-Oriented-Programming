# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Object-Oriented-Programming/blob/Jobsheet-1/JOBSHEET_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Praktikum 02: Membaca Data CSV dengan Pandas
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str) -> pd.DataFrame | None:
    """Membaca data lokasi dari file CSV menggunakan Pandas dengan Exception Handling."""
    try:
        df = pd.read_csv(nama_file)
        print("✔ Berhasil membaca file CSV.")
        return df
    except FileNotFoundError:
        print(f"❌ Error: File '{nama_file}' tidak ditemukan.")
        return None
    except Exception as e:
        print(f"❌ Error saat membaca CSV: {e}")
        return None

# Eksekusi fungsi dan inspeksi data
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)

if df_lokasi is not None:
    print("\n--- 5 Baris Pertama Data ---")
    print(df_lokasi.head())
    print("\n--- Informasi Struktur Data ---")
    print(df_lokasi.info())
    print("\n--- Dimensi Data (Baris, Kolom) ---")
    print(df_lokasi.shape)
# Out:
# ✔ Berhasil membaca file CSV.
#
# --- 5 Baris Pertama Data ---
#                        Nama  Latitude  Longitude            Tipe  \
# 0               Lawang Sewu   -6.9840   110.4105  Wisata Sejarah
# 1              Simpang Lima   -6.9929   110.4200        Landmark
# 2  Masjid Agung Jawa Tengah   -6.9892   110.4452   Tempat Ibadah
# 3     Klenteng Sam Poo Kong   -6.9980   110.4030   Tempat Ibadah
# 4              Brown Canyon   -7.0375   110.4875     Wisata Alam
#
#                                            Deskripsi
# 0   Bangunan bersejarah peninggalan Belanda denga...
# 1  Alun-alun pusat kota Semarang, tempat berkumpu...
# 2   Masjid besar dengan arsitektur megah dan mena...
# 3   Klenteng bersejarah peninggalan Laksamana Che...
# 4  Tebing bekas penambangan galian C yang unik me...
#
# --- Informasi Struktur Data ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nama       10 non-null     object
#  1   Latitude   10 non-null     float64
#  2   Longitude  10 non-null     float64
#  3   Tipe       10 non-null     object
#  4   Deskripsi  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes
# None
#
# --- Dimensi Data (Baris, Kolom) ---
# (10, 5)

# %%
# Praktikum 03: Struktur Kelas OOP (Model Data Geografis)

class Lokasi:
    """Kelas dasar (Parent Class) untuk merepresentasikan koordinat geografis."""
    def __init__(self, nama: str, latitude: float, longitude: float, tipe: str, deskripsi: str):
        self.nama = nama
        self.latitude = float(latitude)
        self.longitude = float(longitude)
        self.tipe = tipe
        self.deskripsi = deskripsi

    def get_koordinat(self) -> tuple:
        """Mengembalikan pasangan latitude dan longitude dalam bentuk tuple."""
        return (self.latitude, self.longitude)

    def tampilkan_info(self) -> str:
        """Mengembalikan string informasi dasar untuk marker."""
        return f"<b>{self.nama}</b> ({self.tipe})<br>{self.deskripsi}"


class TempatWisata(Lokasi):
    """Subclass untuk entitas Wisata, mewarisi dari kelas Lokasi."""
    def __init__(self, nama: str, latitude: float, longitude: float, tipe: str, deskripsi: str):
        super().__init__(nama, latitude, longitude, tipe, deskripsi)

    def tampilkan_info(self) -> str:
        """Polymorphism: Menambahkan ikon visual atau modifikasi informasi tempat wisata."""
        return f"🗺️ <b>[WISATA] {self.nama}</b><br>📌 {self.deskripsi}"


class Kuliner(Lokasi):
    """Subclass untuk entitas Kuliner, mewarisi dari kelas Lokasi."""
    def __init__(self, nama: str, latitude: float, longitude: float, tipe: str, deskripsi: str):
        super().__init__(nama, latitude, longitude, tipe, deskripsi)

    def tampilkan_info(self) -> str:
        """Polymorphism: Menambahkan ikon visual khas makanan/kuliner."""
        return f"🍲 <b>[KULINER] {self.nama}</b><br>😋 {self.deskripsi}"

# %%
# Praktikum 04: Iterasi DataFrame ke Objek OOP

def buat_objek_dari_dataframe(df: pd.DataFrame) -> list:
    """Mengiterasi baris DataFrame dan mengembalikan daftar objek lokasi."""
    daftar_objek = []

    for index, row in df.iterrows():
        nama = row['Nama']
        lat = row['Latitude']
        lon = row['Longitude']
        tipe = row['Tipe']
        deskripsi = row['Deskripsi']

        # Pengkondisian tipe objek (Polymorphism & Inheritance)
        if "Wisata" in tipe or tipe == "Landmark":
            objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
        elif tipe == "Kuliner":
            objek = Kuliner(nama, lat, lon, tipe, deskripsi)
        else:
            objek = Lokasi(nama, lat, lon, tipe, deskripsi)

        daftar_objek.append(objek)

    return daftar_objek

# Mengubah data dari Praktikum 2 menjadi list objek
if df_lokasi is not None:
    daftar_lokasi_objek = buat_objek_dari_dataframe(df_lokasi)
    print(f"✔ Berhasil membuat {len(daftar_lokasi_objek)} objek berbasis OOP.")

    # Uji coba menampilkan salah satu info objek
    print("\nUji coba pemanggilan metode objek pertama:")
    print(daftar_lokasi_objek[0].tampilkan_info())
# Out:
# ✔ Berhasil membuat 10 objek berbasis OOP.
#
# Uji coba pemanggilan metode objek pertama:
# 🗺️ <b>[WISATA] Lawang Sewu</b><br>📌  Bangunan bersejarah peninggalan Belanda dengan banyak pintu.

# %%
# Praktikum 05: Visualisasi Peta Interaktif dengan Folium
import folium

# Inisialisasi peta berpusat di Semarang
koordinat_semarang = [-6.9929, 110.4200]
peta_semarang = folium.Map(location=koordinat_semarang, zoom_start=12)

# Tambahkan marker secara dinamis dari daftar objek lokasi (menggunakan Polymorphism)
for lokasi in daftar_lokasi_objek:
    # Menentukan warna ikon berdasarkan tipe kelas objek
    if isinstance(lokasi, TempatWisata):
        warna_ikon = 'blue'
        ikon_visual = 'cloud'
    elif isinstance(lokasi, Kuliner):
        warna_ikon = 'orange'
        ikon_visual = 'info-sign'
    else:
        warna_ikon = 'green'
        ikon_visual = 'home'

    # Buat marker dan tambahkan ke peta
    folium.Marker(
        location=lokasi.get_koordinat(),
        popup=folium.Popup(lokasi.tampilkan_info(), max_width=300),
        tooltip=f"Klik untuk info {lokasi.nama}",
        icon=folium.Icon(color=warna_ikon, icon=ikon_visual)
    ).add_to(peta_semarang)

# Simpan hasil ke file HTML
peta_semarang.save("peta_semarang.html")
print("✔ Peta berhasil dibuat dan disimpan sebagai 'peta_semarang.html'.")

# Menampilkan peta langsung di Google Colab
peta_semarang
# Out:
# ✔ Peta berhasil dibuat dan disimpan sebagai 'peta_semarang.html'.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9295afeb2cd2ec27d2b4855a4db19ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9295afeb2cd2ec27d2b4855a4db19ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9295afeb2cd2ec27d2b4855a4db19ab = L.map(
#                 &quot;map_e9295afeb2cd2ec27d2b4855a4db19ab&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bffee79d21a2c1beaef147bc7e50b72e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bffee79d21a2c1beaef147bc7e50b72e.addTo(map_e9295afeb2cd2ec27d2b4855a4db19ab);
#
#
#             var marker_767bc0bf91800e0a3bafe97abb46967a = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_e9295afeb2cd2ec27d2b4855a4db19ab);
#
#
#             var icon_7118d0502a97da631a320a7d61fa5a7a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3a578acd6fb2d46827bfed3bfb273e1f = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d01138cb3965722cebbf52305ccbf77b = $(`&lt;div id=&quot;html_d01138cb3965722cebbf52305ccbf77b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🗺️ &lt;b&gt;[WISATA] Lawang Sewu&lt;/b&gt;&lt;br&gt;📌  Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;/div&gt;`)[0];
#                 popup_3a578acd6fb2d46827bfed3bfb273e1f.setContent(html_d01138cb3965722cebbf52305ccbf77b);
#
#
#
#         marker_767bc0bf91800e0a3bafe97abb46967a.bindPopup(popup_3a578acd6fb2d46827bfed3bfb273e1f)
#         ;
#
#
#
#
#             marker_767bc0bf91800e0a3bafe97abb46967a.bindTooltip(
#                 `&lt;div&gt;
#                      Klik untuk info Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_767bc0bf91800e0a3bafe97abb46967a.setIcon(icon_7118d0502a97da631a320a7d61fa5a7a);
#
#
#             var marker_1b7bb8bd061e12195dc4c68cad056c37 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_e9295afeb2cd2ec27d2b4855a4db19ab);
#
#
#             var icon_e6c2b75084955a9fe893c2169e300ca4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d52f0f0324a8c9bbcdfbe71d7efb1f42 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b2b8aa24c0b435b0a9b552fa3f919279 = $(`&lt;div id=&quot;html_b2b8aa24c0b435b0a9b552fa3f919279&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🗺️ &lt;b&gt;[WISATA] Simpang Lima&lt;/b&gt;&lt;br&gt;📌 Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;/div&gt;`)[0];
#                 popup_d52f0f0324a8c9bbcdfbe71d7efb1f42.setContent(html_b2b8aa24c0b435b0a9b552fa3f919279);
#
#
#
#         marker_1b7bb8bd061e12195dc4c68cad056c37.bindPopup(popup_d52f0f0324a8c9bbcdfbe71d7efb1f42)
#         ;
#
#
#
#
#             marker_1b7bb8bd061e12195dc4c68cad056c37.bindTooltip(
#                 `&lt;div&gt;
#                      Klik untuk info Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1b7bb8bd061e12195dc4c68cad056c37.setIcon(icon_e6c2b75084955a9fe893c2169e300ca4);
#
#
#             var marker_e77cce5a4d5246a2cabe0a34b81ded97 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_e9295afeb2cd2ec27d2b4855a4db19ab);
#
#
#             var icon_a93f55c5a0999e44ff9c9efefc3bea4e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_734897ed3d03aa42d61a252553c7d5b8 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });

# %%
# Praktikum 06: File Handling (Menulis Laporan Log SIG)
import datetime

NAMA_FILE_LOG = "log_sistem_sig.txt"

# 1. Menulis Header Laporan (Mode 'w' - Overwrite / Write baru)
with open(NAMA_FILE_LOG, 'w', encoding='utf-8') as f:
    f.write("==================================================\n")
    f.write("       LAPORAN LOG MINI PROJECT SIG SEMARANG       \n")
    f.write(f" Waktu Pembuatan: {datetime.datetime.now()}\n")
    f.write("==================================================\n\n")
print("✔ Sukses menginisialisasi file log (Mode 'w').")

# 2. Menambahkan Rincian Objek (Mode 'a' - Append)
with open(NAMA_FILE_LOG, 'a', encoding='utf-8') as f:
    f.write(f"Total objek terdaftar dalam sistem: {len(daftar_lokasi_objek)} lokasi.\n\n")
    f.write("Daftar Lokasi dan Koordinat:\n")

    for idx, lokasi in enumerate(daftar_lokasi_objek, 1):
        line = f"{idx}. {lokasi.nama} | Tipe: {lokasi.tipe} | Koordinat: {lokasi.get_koordinat()}\n"
        f.write(line)

    f.write("\n======================= END =======================\n")
print("✔ Sukses menambahkan data rincian objek ke dalam log (Mode 'a').")

# 3. Membaca kembali isi file log untuk memastikan isinya benar
print("\n--- Isi Berkas log_sistem_sig.txt ---")
with open(NAMA_FILE_LOG, 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# ✔ Sukses menginisialisasi file log (Mode 'w').
# ✔ Sukses menambahkan data rincian objek ke dalam log (Mode 'a').
#
# --- Isi Berkas log_sistem_sig.txt ---
# ==================================================
#        LAPORAN LOG MINI PROJECT SIG SEMARANG
#  Waktu Pembuatan: 2026-06-18 15:49:29.712924
# ==================================================
#
# Total objek terdaftar dalam sistem: 10 lokasi.
#
# Daftar Lokasi dan Koordinat:
# 1. Lawang Sewu | Tipe: Wisata Sejarah | Koordinat: (-6.984, 110.4105)
# 2. Simpang Lima | Tipe: Landmark | Koordinat: (-6.9929, 110.42)
# 3. Masjid Agung Jawa Tengah | Tipe: Tempat Ibadah | Koordinat: (-6.9892, 110.4452)
# 4. Klenteng Sam Poo Kong | Tipe: Tempat Ibadah | Koordinat: (-6.998, 110.403)
# 5. Brown Canyon | Tipe: Wisata Alam | Koordinat: (-7.0375, 110.4875)
# 6. Lumpia Gang Lombok | Tipe: Kuliner | Koordinat: (-6.9718, 110.4255)
# 7. Kota Lama | Tipe: Wisata Sejarah | Koordinat: (-6.969, 110.425)
# 8. Pantai Marina | Tipe: Wisata Alam | Koordinat: (-6.9585, 110.3875)
# 9. Kampoeng Kopi Banaran | Tipe: Wisata Alam | Koordinat: (-7.278, 110.401)
# 10. Toko Oen | Tipe: Kuliner | Koordinat: (-6.9715, 110.4235)
#
# ======================= END =======================

# %%
# ==========================================
# 1. PERSIAPAN ABSTRACT BASE CLASS & MODEL
# ==========================================
from abc import ABC, abstractmethod
import pandas as pd
import folium
import datetime

class GeoEntity(ABC):
    """
    Abstract Base Class (ABC) sebagai cetak biru (blueprint)
    untuk semua entitas spasial/geografis.
    """
    def __init__(self, nama: str, latitude: float, longitude: float, tipe: str, deskripsi: str):
        self.nama = nama
        self.latitude = float(latitude)
        self.longitude = float(longitude)
        self.tipe = tipe
        self.deskripsi = deskripsi

    @abstractmethod
    def tampilkan_info(self) -> str:
        """Method abstrak yang WAJIB diimplementasikan oleh setiap subclass."""
        pass

    def get_koordinat(self) -> tuple:
        """Mengembalikan pasangan latitude dan longitude dalam bentuk tuple."""
        return (self.latitude, self.longitude)


class TempatWisata(GeoEntity):
    """Subclass untuk entitas Wisata, mewarisi dari GeoEntity."""
    def tampilkan_info(self) -> str:
        return f"🗺️ <b>[WISATA] {self.nama}</b><br>📌 {self.deskripsi}"


class Kuliner(GeoEntity):
    """Subclass untuk entitas Kuliner, mewarisi dari GeoEntity."""
    def tampilkan_info(self) -> str:
        return f"🍲 <b>[KULINER] {self.nama}</b><br>😋 {self.deskripsi}"


class TempatIbadah(GeoEntity):
    """Subclass tambahan untuk Tempat Ibadah, mewarisi dari GeoEntity."""
    def tampilkan_info(self) -> str:
        return f"🕌 <b>[IBADAH] {self.nama}</b><br>✨ {self.deskripsi}"


# ==========================================
# 2. FUNGSI LOAD DATA & EXCEPTION HANDLING
# ==========================================
def load_and_validate_data(nama_file: str) -> list:
    """
    Membaca CSV dengan pengondisian tipe data, validasi kolom,
    dan Exception Handling yang kuat.
    """
    daftar_objek = []
    kolom_wajib = {'Nama', 'Latitude', 'Longitude', 'Tipe', 'Deskripsi'}

    try:
        # Membaca file CSV menggunakan Pandas
        df = pd.read_csv(nama_file)

        # Validasi ketersediaan kolom wajib (KeyError handling secara manual)
        if not kolom_wajib.issubset(df.columns):
            hilang = kolom_wajib - set(df.columns)
            raise KeyError(f"Kolom wajib tidak ditemukan di CSV: {hilang}")

        # Mengiterasi baris demi baris
        for index, row in df.iterrows():
            try:
                nama = str(row['Nama']).strip()
                lat = float(row['Latitude'])    # Memicu ValueError jika bukan angka
                lon = float(row['Longitude'])   # Memicu ValueError jika bukan angka
                tipe = str(row['Tipe']).strip()
                deskripsi = str(row['Deskripsi']).strip()

                # Pengkondisian tipe objek berdasarkan kolom 'Tipe'
                if "Wisata" in tipe or tipe == "Landmark":
                    objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
                elif "Kuliner" in tipe:
                    objek = Kuliner(nama, lat, lon, tipe, deskripsi)
                elif "Ibadah" in tipe:
                    objek = TempatIbadah(nama, lat, lon, tipe, deskripsi)
                else:
                    # Default jika tipe lain tidak masuk spesifikasi khusus
                    objek = TempatWisata(nama, lat, lon, tipe, deskripsi)

                daftar_objek.append(objek)

            except ValueError:
                print(f"⚠ Baris {index+1} dilewati: Koordinat Latitude/Longitude harus berupa angka!")
            except Exception as e:
                print(f"⚠ Gagal memproses baris {index+1}: {e}")

        print(f"✔ Validasi sukses. {len(daftar_objek)} objek berhasil dimuat ke memori.")
        return daftar_objek

    except FileNotFoundError:
        print(f"❌ Error kritis: File '{nama_file}' tidak ditemukan!")
        return []
    except KeyError as ke:
        print(f"❌ Error struktur file: {ke}")
        return []
    except Exception as e:
        print(f"❌ Terjadi kesalahan sistem: {e}")
        return []


# ==========================================
# 3. FUNGSI PENCARIAN / FILTER DATA
# ==========================================
def cari_lokasi(daftar_objek: list, kata_kunci: str) -> list:
    """Memfilter daftar objek berdasarkan nama atau deskripsi (Case-Insensitive)."""
    hasil_pencarian = [
        obj for obj in daftar_objek
        if kata_kunci.lower() in obj.nama.lower() or kata_kunci.lower() in obj.deskripsi.lower()
    ]
    return hasil_pencarian


# ==========================================
# 4. PROSES EKSEKUSI UTAMA (MAIN PROGRAM)
# ==========================================
NAMA_FILE_CSV = "lokasi_semarang.csv"

# Mengisi & memvalidasi objek data
semua_lokasi = load_and_validate_data(NAMA_FILE_CSV)

if semua_lokasi:
    # --- Contoh Fitur Pencarian ---
    kata_kunci_cari = "Lumpia"
    hasil_filter = cari_lokasi(semua_lokasi, kata_kunci_cari)

    print(f"\n--- Hasil Pencarian dengan Kata Kunci '{kata_kunci_cari}' ---")
    for item in hasil_filter:
        print(f"- {item.nama} ({item.tipe})")

    # --- Pembuatan Peta dengan Custom Marker ---
    koordinat_semarang = [-6.9929, 110.4200]
    peta_tugas = folium.Map(location=koordinat_semarang, zoom_start=12)

    for lokasi in semua_lokasi:
        # Penentuan warna marker dan ikon visual berdasarkan tipe objek konkret
        if isinstance(lokasi, TempatWisata):
            warna_ikon = 'blue'
            ikon_visual = 'camera'
        elif isinstance(lokasi, Kuliner):
            warna_ikon = 'orange'
            ikon_visual = 'cutlery'
        elif isinstance(lokasi, TempatIbadah):
            warna_ikon = 'green'
            ikon_visual = 'heart'
        else:
            warna_ikon = 'gray'
            ikon_visual = 'info-sign'

        # Menambahkan marker ke peta
        folium.Marker(
            location=lokasi.get_koordinat(),
            popup=folium.Popup(lokasi.tampilkan_info(), max_width=300),
            tooltip=lokasi.nama,
            icon=folium.Icon(color=warna_ikon, icon=ikon_visual, prefix='fa') # Menggunakan FontAwesome Icon
        ).add_to(peta_tugas)

    # Menyimpan peta ke berkas HTML eksternal
    peta_tugas.save("peta_semarang_tugas.html")
    print("\n✔ Peta tugas interaktif sukses dibuat sebagai 'peta_semarang_tugas.html'.")
# Out:
# ✔ Validasi sukses. 10 objek berhasil dimuat ke memori.
#
# --- Hasil Pencarian dengan Kata Kunci 'Lumpia' ---
# - Lumpia Gang Lombok (Kuliner)
#
# ✔ Peta tugas interaktif sukses dibuat sebagai 'peta_semarang_tugas.html'.

# %%
# Tampilkan peta di notebook Google Colab
peta_tugas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ad0ae84c860740484d9211555ac7f35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ad0ae84c860740484d9211555ac7f35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ad0ae84c860740484d9211555ac7f35 = L.map(
#                 &quot;map_7ad0ae84c860740484d9211555ac7f35&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f50988b7d7b7542d78db9934864930d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f50988b7d7b7542d78db9934864930d6.addTo(map_7ad0ae84c860740484d9211555ac7f35);
#
#
#             var marker_34afb6687306fa9e1f13a8879b014fee = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_7ad0ae84c860740484d9211555ac7f35);
#
#
#             var icon_4b00484a0c8e2588bf83a8350a054a6b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e666c99bacfa544b53205fc1ce2f251a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_995cdc5d04d9bf0364f5892a98377b5f = $(`&lt;div id=&quot;html_995cdc5d04d9bf0364f5892a98377b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🗺️ &lt;b&gt;[WISATA] Lawang Sewu&lt;/b&gt;&lt;br&gt;📌 Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;/div&gt;`)[0];
#                 popup_e666c99bacfa544b53205fc1ce2f251a.setContent(html_995cdc5d04d9bf0364f5892a98377b5f);
#
#
#
#         marker_34afb6687306fa9e1f13a8879b014fee.bindPopup(popup_e666c99bacfa544b53205fc1ce2f251a)
#         ;
#
#
#
#
#             marker_34afb6687306fa9e1f13a8879b014fee.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_34afb6687306fa9e1f13a8879b014fee.setIcon(icon_4b00484a0c8e2588bf83a8350a054a6b);
#
#
#             var marker_687996e72b0107d5da2899c99c8f665b = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_7ad0ae84c860740484d9211555ac7f35);
#
#
#             var icon_3396859602c3b2504920d5a0cfc4072d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a736703e5aed48786b12c6c6fc403a5e = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c38f81003bacf6e539a3932349b90990 = $(`&lt;div id=&quot;html_c38f81003bacf6e539a3932349b90990&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🗺️ &lt;b&gt;[WISATA] Simpang Lima&lt;/b&gt;&lt;br&gt;📌 Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;/div&gt;`)[0];
#                 popup_a736703e5aed48786b12c6c6fc403a5e.setContent(html_c38f81003bacf6e539a3932349b90990);
#
#
#
#         marker_687996e72b0107d5da2899c99c8f665b.bindPopup(popup_a736703e5aed48786b12c6c6fc403a5e)
#         ;
#
#
#
#
#             marker_687996e72b0107d5da2899c99c8f665b.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_687996e72b0107d5da2899c99c8f665b.setIcon(icon_3396859602c3b2504920d5a0cfc4072d);
#
#
#             var marker_fc01b6f0a3c289b4dc2042a006c8180d = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_7ad0ae84c860740484d9211555ac7f35);
#
#
#             var icon_2672b7e0a97a282979b7d2882af1fbc8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_43296effa3e97b42e8d7229dc1a5a91a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8c0076fdecd89b888f88
